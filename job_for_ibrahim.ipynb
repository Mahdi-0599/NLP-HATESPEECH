# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-0599/NLP-HATESPEECH/blob/master/job_for_ibrahim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
from xgboost import plot_tree, plot_importance

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/miusec-calssifiction/train_features.csv
# /kaggle/input/miusec-calssifiction/README00.txt
# /kaggle/input/miusec-calssifiction/test_features.csv
# /kaggle/input/miusec-calssifiction/valid_labels.csv
# /kaggle/input/miusec-calssifiction/train_labels.csv
# /kaggle/input/miusec-calssifiction/valid_features.csv

# %%
df= pd.read_csv('../input/miusec-calssifiction/train_features.csv')

# %%
df
# Out:
#       trackID                            title  \
# 0        8424          The Calamity [Explicit]
# 1        7923                   Try To Find Me
# 2        2314             Poor Old Dirt Farmer
# 3         810                      Texas Flood
# 4         439                Chopsticks Medley
# ...       ...                              ...
# 7673     6419                  Stop That Train
# 7674     6811             In A Close Encounter
# 7675     1474  Our Lady Of Sorrow (LP Version)
# 7676     8343                        Section X
# 7677     8454            Regular Dose Of Azure
#
#                                                    tags  loudness    tempo  \
# 0     the, you, to, a, not, in, of, that, are, we, w...    -2.824  131.969
# 1     i, the, you, to, and, a, me, it, not, in, my, ...   -11.249  136.510
# 2     the, to, and, a, in, is, on, all, no, have, bu...    -6.932   72.878
# 3     i, the, you, to, and, a, me, it, not, in, my, ...   -12.551   75.381
# ...

# %%
dfl=  pd.read_csv('../input/miusec-calssifiction/train_labels.csv')

# %%
dfl
# Out:
#       trackID                 genre
# 0        8424                 metal
# 1        7923                  folk
# 2        2314                  folk
# 3         810        jazz and blues
# 4         439                  folk
# ...       ...                   ...
# 7673     6419       soul and reggae
# 7674     6811                 metal
# 7675     1474  classic pop and rock
# 7676     8343                 metal
# 7677     8454                 metal
#
# [7678 rows x 2 columns]

# %%
X=pd.merge(df, dfl)

# %%
X
# Out:
#       trackID                            title  \
# 0        8424          The Calamity [Explicit]
# 1        7923                   Try To Find Me
# 2        2314             Poor Old Dirt Farmer
# 3         810                      Texas Flood
# 4         439                Chopsticks Medley
# ...       ...                              ...
# 7673     6419                  Stop That Train
# 7674     6811             In A Close Encounter
# 7675     1474  Our Lady Of Sorrow (LP Version)
# 7676     8343                        Section X
# 7677     8454            Regular Dose Of Azure
#
#                                                    tags  loudness    tempo  \
# 0     the, you, to, a, not, in, of, that, are, we, w...    -2.824  131.969
# 1     i, the, you, to, and, a, me, it, not, in, my, ...   -11.249  136.510
# 2     the, to, and, a, in, is, on, all, no, have, bu...    -6.932   72.878
# 3     i, the, you, to, and, a, me, it, not, in, my, ...   -12.551   75.381
# ...

# %%
from sklearn.preprocessing import LabelEncoder 
  
le = LabelEncoder() 
   
X['tags']= le.fit_transform(X['tags'])

# %%
X
# Out:
#       trackID                            title  tags  loudness    tempo  \
# 0        8424          The Calamity [Explicit]  7003    -2.824  131.969
# 1        7923                   Try To Find Me  3771   -11.249  136.510
# 2        2314             Poor Old Dirt Farmer  6659    -6.932   72.878
# 3         810                      Texas Flood  3277   -12.551   75.381
# 4         439                Chopsticks Medley  6075   -14.566  134.331
# ...       ...                              ...   ...       ...      ...
# 7673     6419                  Stop That Train   872   -10.798  146.624
# 7674     6811             In A Close Encounter   656    -3.759  153.760
# 7675     1474  Our Lady Of Sorrow (LP Version)  5328   -11.883   98.596
# 7676     8343                        Section X  2583    -3.518  101.639
# 7677     8454            Regular Dose Of Azure  1173    -7.217  119.586
#
#       time_signature  key  mode   duration     vect_1  ...  vect_140  \
# ...

# %%
X['title']= le.fit_transform(X['title'])

# %%
X['genre']= le.fit_transform(X['genre'])

# %%
X.dropna(axis=0, subset=['genre'], inplace=True)
y = X.genre              
X.drop(['genre'], axis=1, inplace=True)

# %%
X
# Out:
#       trackID  title  tags  loudness    tempo  time_signature  key  mode  \
# 0        8424   6094  7003    -2.824  131.969               4    0     1
# 1        7923   6725  3771   -11.249  136.510               4    4     1
# 2        2314   4800  6659    -6.932   72.878               4    7     1
# 3         810   6037  3277   -12.551   75.381               3    6     1
# 4         439   1063  6075   -14.566  134.331               4    5     0
# ...       ...    ...   ...       ...      ...             ...  ...   ...
# 7673     6419   5784   872   -10.798  146.624               1    7     1
# 7674     6811   3025   656    -3.759  153.760               4    6     1
# 7675     1474   4600  5328   -11.883   98.596               4   10     1
# 7676     8343   5269  2583    -3.518  101.639               4    4     0
# 7677     8454   4988  1173    -7.217  119.586               4    8     1
#
#        duration     vect_1  ...  vect_139  vect_140  vect_141  vect_142  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import mean_absolute_error ,explained_variance_score, mean_squared_error

# %%
y_train
# Out:
# 947     2
# 2840    0
# 2921    4
# 3861    0
# 4442    6
#        ..
# 5226    0
# 5390    2
# 860     6
# 7603    2
# 7270    0
# Name: genre, Length: 5374, dtype: int64

# %%
parameters = [{
'n_estimators': list(range(100, 501, 100)), 
'learning_rate': [0.01,0.03,0.05,0.07,0.09]
}]
from sklearn.model_selection import GridSearchCV

gsearch = GridSearchCV(estimator=XGBClassifier(),
                       param_grid = parameters, 
                       scoring='neg_mean_absolute_error',
                       n_jobs=4,cv=5,verbose=7)

gsearch.fit(X_train, y_train)

gsearch.best_params_.get('n_estimators'), gsearch.best_params_.get('learning_rate')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed: 39.6min
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed: 97.6min
# [Parallel(n_jobs=4)]: Done 125 out of 125 | elapsed: 193.4min finished
# (500, 0.09)

# %%
def model_assess(model, title = "Default"):
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    #print(confusion_matrix(y_test, preds))
    print('Accuracy', title, ':', round(accuracy_score(y_test, preds), 5), '\n')

# %%
# Naive Bayes
nb = GaussianNB()
model_assess(nb, "Naive Bayes")

# Stochastic Gradient Descent
sgd = SGDClassifier(max_iter=5000, random_state=0)
model_assess(sgd, "Stochastic Gradient Descent")

# KNN
knn = KNeighborsClassifier(n_neighbors=19)
model_assess(knn, "KNN")

# Decission trees
tree = DecisionTreeClassifier()
model_assess(tree, "Decission trees")

# Random Forest
rforest = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
model_assess(rforest, "Random Forest")

# Support Vector Machine
svm = SVC(decision_function_shape="ovo")
model_assess(svm, "Support Vector Machine")

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
model_assess(lg, "Logistic Regression")

# Neural Nets
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5000, 10), random_state=1)
model_assess(nn, "Neural Nets")

# Cross Gradient Booster
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
model_assess(xgb, "Cross Gradient Booster")

# Cross Gradient Booster (Random Forest)
xgbrf = XGBRFClassifier(objective= 'multi:softmax')
model_assess(xgbrf, "Cross Gradient Booster (Random Forest)")
# Out:
# Accuracy Naive Bayes : 0.4184
#
# Accuracy Stochastic Gradient Descent : 0.38889
#
# Accuracy KNN : 0.36806
#
# Accuracy Decission trees : 0.44792
#
# Accuracy Random Forest : 0.60764
#
# Accuracy Support Vector Machine : 0.40408
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy Logistic Regression : 0.43403
#
# Accuracy Neural Nets : 0.2053
#
# Accuracy Cross Gradient Booster : 0.69358
#
# Accuracy Cross Gradient Booster (Random Forest) : 0.60851

# %%
# Final model
xgb = XGBClassifier(n_estimators=250, learning_rate=0.03)
xgb.fit(X_train, y_train)


preds = xgb.predict(X_test)

print('Accuracy', ':', round(accuracy_score(y_test, preds), 5), '\n')
# Out:
# Accuracy : 0.6658
